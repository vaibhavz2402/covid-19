# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %%
response = requests.get('https://api.covid19api.com/all')

# %%
data = response.json()

# %%
df = pd.DataFrame(data)
df
# Out:
#             Country CountryCode Province City CityCode     Lat    Lon  \
# 0       Afghanistan          AF                          33.94  67.71
# 1       Afghanistan          AF                          33.94  67.71
# 2       Afghanistan          AF                          33.94  67.71
# 3       Afghanistan          AF                          33.94  67.71
# 4       Afghanistan          AF                          33.94  67.71
# ...             ...         ...      ...  ...      ...     ...    ...
# 344269     Zimbabwe          ZW                         -19.02  29.15
# 344270     Zimbabwe          ZW                         -19.02  29.15
# 344271     Zimbabwe          ZW                         -19.02  29.15
# 344272     Zimbabwe          ZW                         -19.02  29.15
# 344273     Zimbabwe          ZW                         -19.02  29.15
#
#         Confirmed  Deaths  Recovered  Active                  Date
# 0               0       0          0       0  2020-01-22T00:00:00Z
# 1               0       0          0       0  2020-01-23T00:00:00Z
# 2               0       0          0       0  2020-01-24T00:00:00Z
# 3               0       0          0       0  2020-01-25T00:00:00Z
# 4               0       0          0       0  2020-01-26T00:00:00Z
# ...           ...     ...        ...     ...                   ...
# 344269         29       4          2       0  2020-04-24T00:00:00Z
# 344270         31       4          2       0  2020-04-25T00:00:00Z
# 344271         31       4          2       0  2020-04-26T00:00:00Z
# 344272         32       4          5       0  2020-04-27T00:00:00Z
# 344273         32       4          5       0  2020-04-28T00:00:00Z
#
# [344274 rows x 12 columns]

# %%
df = df.drop(columns = ['CityCode'])

# %%
df.shape
# Out:
# (344274, 11)

# %% [markdown]
# #### Spliting TimeSeries

# %%
df['Date'][0].split('T')[0].split('-')
# Out:
# ['2020', '01', '22']

# %%
df['Year'] = pd.Series()
df['Month'] = pd.Series()

# %%
end  = df.shape[0]

for i in range(0, end):
    li = []
    li = df['Date'][i].split('T')[0].split('-')
    df['Year'][i] = int(li[0])
    df['Month'][i] = int(li[1])
    df['Date'][i] = int(li[2])
    df['Active'][i] = df['Confirmed'][i] - df['Deaths'][i] - df['Recovered'][i]

# %%
df = df.drop(columns = ['City', 'Province'])

# %%
df.head()
# Out:
#        Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 0  Afghanistan          AF  33.94  67.71          0       0          0
# 1  Afghanistan          AF  33.94  67.71          0       0          0
# 2  Afghanistan          AF  33.94  67.71          0       0          0
# 3  Afghanistan          AF  33.94  67.71          0       0          0
# 4  Afghanistan          AF  33.94  67.71          0       0          0
#
#    Active Date  Year  Month
# 0       0   22  2020      1
# 1       0   23  2020      1
# 2       0   24  2020      1
# 3       0   25  2020      1
# 4       0   26  2020      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344274 entries, 0 to 344273
# Data columns (total 11 columns):
# Country        344274 non-null object
# CountryCode    344274 non-null object
# Lat            344274 non-null object
# Lon            344274 non-null object
# Confirmed      344274 non-null int64
# Deaths         344274 non-null int64
# Recovered      344274 non-null int64
# Active         344274 non-null int64
# Date           344274 non-null object
# Year           344274 non-null int32
# Month          344274 non-null int32
# dtypes: int32(2), int64(4), object(5)
# memory usage: 26.3+ MB

# %%
df.Year = df.Year.astype('int')
df.Month = df.Month.astype('int')

# %%
code = df.CountryCode.unique()
code
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'KH', 'CM', 'CA', 'CV', 'CF',
#        'TD', 'CL', 'CN', 'CO', 'CG', 'CD', 'CR', 'CI', 'HR', 'CU', 'CY',
#        'CZ', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER', 'EE',
#        'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR', 'GD',
#        'GT', 'GN', 'GW', 'GY', 'HT', 'VA', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IE', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KR',
#        'KW', 'KG', 'LA', 'LV', 'LB', 'LR', 'LY', 'LI', 'LT', 'LU', 'MK',
#        'MG', 'MW', 'MY', 'MV', 'ML', 'MT', 'MR', 'MU', 'MX', 'MD', 'MC',
#        'MN', 'ME', 'MA', 'MZ', 'MM', 'NA', 'NP', 'NL', 'NZ', 'NI', 'NE',
#        'NG', 'NO', 'OM', 'PK', 'PS', 'PA', 'PG', 'PY', 'PE', 'PH', 'PL',
#        'PT', 'QA', 'XK', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'SM', 'ST',
#        'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SO', 'ZA', 'SS',
#        'ES', 'LK', 'SD', 'SR', 'SZ', 'SE', 'CH', 'SY', 'TW', 'TZ', 'TH',
#        'TL', 'TG', 'TT', 'TN', 'TR', 'UG', 'UA', 'AE', 'GB', 'US', 'UY',
#        'UZ', 'VE', 'VN', 'EH', 'YE', 'ZM', 'ZW'], dtype=object)

# %%
len(code)
# Out:
# 183

# %%
data_frame = [*range(0,len(code),1)]     #creating list for storing country wise data 
i = 0
for val in code:
    data_frame[i] = df[df.CountryCode == val]
    i = i+1

# %%
type(data_frame[100])
# Out:
# pandas.core.frame.DataFrame

# %%
for frame in range(len(data_frame)):
    data_frame[frame] = data_frame[frame].reset_index(drop = True)

# %%
data_frame[100]
# Out:
#    Country CountryCode     Lat   Lon  Confirmed  Deaths  Recovered  Active  \
# 0   Malawi          MW  -13.25  34.3          0       0          0       0
# 1   Malawi          MW  -13.25  34.3          0       0          0       0
# 2   Malawi          MW  -13.25  34.3          0       0          0       0
# 3   Malawi          MW  -13.25  34.3          0       0          0       0
# 4   Malawi          MW  -13.25  34.3          0       0          0       0
# ..     ...         ...     ...   ...        ...     ...        ...     ...
# 93  Malawi          MW  -13.25  34.3         33       3          4      26
# 94  Malawi          MW  -13.25  34.3         33       3          4      26
# 95  Malawi          MW  -13.25  34.3         34       3          4      27
# 96  Malawi          MW  -13.25  34.3         36       3          4      29
# 97  Malawi          MW  -13.25  34.3         36       3          5      28
#
#    Date  Year  Month
# 0    22  2020      1
# 1    23  2020      1
# 2    24  2020      1
# 3    25  2020      1
# 4    26  2020      1
# ..  ...   ...    ...
# 93   24  2020      4
# 94   25  2020      4
# 95   26  2020      4
# 96   27  2020      4
# 97   28  2020      4
#
# [98 rows x 11 columns]

# %%
type(data_frame)
# Out:
# list

# %%
for frame in range(len(data_frame)):
    print(frame, code[frame],':', data_frame[frame].shape[0])
# Out:
# 0 AF : 98
# 1 AL : 98
# 2 DZ : 98
# 3 AD : 98
# 4 AO : 98
# 5 AG : 98
# 6 AR : 98
# 7 AM : 98
# 8 AU : 784
# 9 AT : 98
# 10 AZ : 98
# 11 BS : 98
# 12 BH : 98
# 13 BD : 98
# 14 BB : 98
# 15 BY : 98
# 16 BE : 98
# 17 BZ : 98
# 18 BJ : 98
# 19 BT : 98
# 20 BO : 98
# 21 BA : 98
# 22 BW : 98
# 23 BR : 98
# 24 BN : 98
# 25 BG : 98
# 26 BF : 98
# 27 BI : 98
# 28 KH : 98
# 29 CM : 98
# 30 CA : 1372
# 31 CV : 98
# 32 CF : 98
# 33 TD : 98
# 34 CL : 98
# 35 CN : 3234
# 36 CO : 98
# 37 CG : 98
# 38 CD : 98
# 39 CR : 98
# 40 CI : 98
# 41 HR : 98
# 42 CU : 98
# 43 CY : 98
# 44 CZ : 98
# 45 DK : 294
# 46 DJ : 98
# 47 DM : 98
# 48 DO : 98
# 49 EC : 98
# 50 EG : 98
# 51 SV : 98
# 52 GQ : 98
# 53 ER : 98
# 54 EE : 98
# 55 ET : 98
# 56 FJ : 98
# 57 FI : 98
# 58 FR : 1078
# 59 GA : 98
# 60 GM : 98
# 61 GE : 98
# 62 DE : 98
# 63 GH : 98
# 64 GR : 98
# 65 GD : 98
# 66 GT : 98
# 67 GN : 98
# 68 GW : 98
# 69 GY : 98
# 70 HT : 98
# 71 VA : 98
# 72 HN : 98
# 73 HU : 98
# 74 IS : 98
# 75 IN : 98
# 76 ID : 98
# 77 IR : 98
# 78 IQ : 98
# 79 IE : 98
# 80 IL : 98
# 81 IT : 98
# 82 JM : 98
# 83 JP : 98
# 84 JO : 98
# 85 KZ : 98
# 86 KE : 98
# 87 KR : 98
# 88 KW : 98
# 89 KG : 98
# 90 LA : 98
# 91 LV : 98
# 92 LB : 98
# 93 LR : 98
# 94 LY : 98
# 95 LI : 98
# 96 LT : 98
# 97 LU : 98
# 98 MK : 98
# 99 MG : 98
# 100 MW : 98
# 101 MY : 98
# 102 MV : 98
# 103 ML : 98
# 104 MT : 98
# 105 MR : 98
# 106 MU : 98
# 107 MX : 98
# 108 MD : 98
# 109 MC : 98
# 110 MN : 98
# 111 ME : 98
# 112 MA : 98
# 113 MZ : 98
# 114 MM : 98
# 115 NA : 98
# 116 NP : 98
# 117 NL : 490
# 118 NZ : 98
# 119 NI : 98
# 120 NE : 98
# 121 NG : 98
# 122 NO : 98
# 123 OM : 98
# 124 PK : 98
# 125 PS : 98
# 126 PA : 98
# 127 PG : 98
# 128 PY : 98
# 129 PE : 98
# 130 PH : 98
# 131 PL : 98
# 132 PT : 98
# 133 QA : 98
# 134 XK : 98
# 135 RO : 98
# 136 RU : 98
# 137 RW : 98
# 138 KN : 98
# 139 LC : 98
# 140 VC : 98
# 141 SM : 98
# 142 ST : 98
# 143 SA : 98
# 144 SN : 98
# 145 RS : 98
# 146 SC : 98
# 147 SL : 98
# 148 SG : 98
# 149 SK : 98
# 150 SI : 98
# 151 SO : 98
# 152 ZA : 98
# 153 SS : 98
# 154 ES : 98
# 155 LK : 98
# 156 SD : 98
# 157 SR : 98
# 158 SZ : 98
# 159 SE : 98
# 160 CH : 98
# 161 SY : 98
# 162 TW : 98
# 163 TZ : 98
# 164 TH : 98
# 165 TL : 98
# 166 TG : 98
# 167 TT : 98
# 168 TN : 98
# 169 TR : 98
# 170 UG : 98
# 171 UA : 98
# 172 AE : 98
# 173 GB : 1078
# 174 US : 318794
# 175 UY : 98
# 176 UZ : 98
# 177 VE : 98
# 178 VN : 98
# 179 EH : 98
# 180 YE : 98
# 181 ZM : 98
# 182 ZW : 98

# %%
data_frame[174].head()
# Out:
#                     Country CountryCode    Lat      Lon  Confirmed  Deaths  \
# 0  United States of America          US  36.56   -85.08          0       0
# 1  United States of America          US  44.45  -116.78          0       0
# 2  United States of America          US  42.39   -96.57          0       0
# 3  United States of America          US  40.13  -122.24          0       0
# 4  United States of America          US  37.94   -93.32          0       0
#
#    Recovered  Active Date  Year  Month
# 0          0       0   22  2020      1
# 1          0       0   22  2020      1
# 2          0       0   22  2020      1
# 3          0       0   22  2020      1
# 4          0       0   22  2020      1

# %% [markdown]
# ##### Countries containing more than 98 values have data for its cities also, So we have to segregate the data city wise for those countries

# %% [markdown]
# ### Finding countries with city data

# %%
big_index = [] 
for frame in range(0,len(data_frame)):
    if(data_frame[frame].shape[0] > 98):
        big_index.append(frame)

# %%
big_index
# Out:
# [8, 30, 35, 45, 58, 117, 173, 174]

# %%
big_countries = [*range(0,len(big_index),1)]
big_code = [*range(0,len(big_index),1)]

j = 0
for i in big_index:
    big_countries[j] = data_frame[i]
    big_code[j] = code[i]
    j = j+1

# %%
big_code
# Out:
# ['AU', 'CA', 'CN', 'DK', 'FR', 'NL', 'GB', 'US']

# %%
big_countries[7]
# Out:
#                          Country CountryCode    Lat      Lon  Confirmed  \
# 0       United States of America          US  36.56   -85.08          0
# 1       United States of America          US  44.45  -116.78          0
# 2       United States of America          US  42.39   -96.57          0
# 3       United States of America          US  40.13  -122.24          0
# 4       United States of America          US  37.94   -93.32          0
# ...                          ...         ...    ...      ...        ...
# 318789  United States of America          US  38.78   -97.65         20
# 318790  United States of America          US  33.28   -88.09         47
# 318791  United States of America          US  33.95   -91.74        755
# 318792  United States of America          US  37.09   -95.71          0
# 318793  United States of America          US  33.39   -95.67          1
#
#         Deaths  Recovered  Active Date  Year  Month
# 0            0          0       0   22  2020      1
# 1            0          0       0   22  2020      1
# 2            0          0       0   22  2020      1
# 3            0          0       0   22  2020      1
# 4            0          0       0   22  2020      1
# ...        ...        ...     ...  ...   ...    ...
# 318789       2          0      18   28  2020      4
# 318790       1          0      46   28  2020      4
# 318791       0          0     755   28  2020      4
# 318792       0     115936 -115936   28  2020      4
# 318793       0          0       1   28  2020      4
#
# [318794 rows x 11 columns]

# %%
code = code.tolist()

for i in big_index:
    del data_frame[i]
    del code[i]

# %% [markdown]
# ### Dumping the data to files
# These files will be used for further manipulation and visulaization

# %%
import pickle

# %%
with open('onlyCountries.data', 'wb') as filehandle:
    # store the data as binary data stream
    pickle.dump(data_frame, filehandle)

# %%
with open('onlyCountriesCode.data', 'wb') as filehandle:
    # store the data as binary data stream
    pickle.dump(code, filehandle)

# %%
with open('countriesWithCities.data', 'wb') as filehandle:
    # store the data as binary data stream
    pickle.dump(big_countries, filehandle)

# %%
with open('countriesWithCitiesCode.data', 'wb') as filehandle:
    # store the data as binary data stream
    pickle.dump(big_code, filehandle)
